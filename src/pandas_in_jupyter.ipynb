# %%
import pandas as pd

# %%
bundestag_19 = pd.read_csv("https://github.com/Ceyron/machine-learning-and-simulation/files/7235038/19th_bundestag_example.csv")
bundestag_19
# Out:
#      party  result  seats           chairman  budget_2020_pro  \
# 0  cdu/csu    33.1    245    Ralph Brinkhaus              236
# 1      spd    20.5    152     Rolf Mützenich              135
# 2      afd    12.6     87  Alexander Gauland                0
# 3      fdp    10.7     80  Christian Lindner                0
# 4    linke     9.2     69    Dietmar Bartsch                0
# 5   gruene     8.9     67    Anton Hofreiter                0
# 6   others     5.0      9               ohne                0
#
#    budget_2020_con  budget_2020_neutral
# 0                0                   10
# 1                0                   17
# 2               83                    8
# 3               69                   10
# 4               57                   12
# 5               60                    7
# 6                1                    3
